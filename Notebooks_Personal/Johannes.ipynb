# %% [markdown]
# ## Import & DF's

# %%
import pandas as pd

from Utils.DataExploration import explore_dataframe
from Utils.FeatureExploration import explore_features

# %%
df_airports = pd.read_csv("../data/airportsdata/airports.csv")
df_iata = pd.read_csv("../data/airportsdata/iata_macs.csv")

df_train = pd.read_csv("../data/zindi/train.csv")

# %% [markdown]
# ## First EDA

# %%
explore_features(df_airports)
# Out:
# ID  Name       non-null count  D-Type   Feature Summary
# 0   icao       28270 non-null  object   only unique Values
# 1   iata       7859 (72.20%)   object   only unique Values
# 2   name       28270 non-null  object   Fazenda Santa Maria Airport (14), Fazenda Sao Joao Airport (13), Fazenda Sao Francisco Airport (10), Smith Field (10), Aeroclube Airport (9)
# 3   city       25440 (10.01%)  object   Corumba (75), Itaituba (51), Wasilla (45), Greenville (28), Guiscriff (27)
# 4   subd       27497 (2.73%)   object   Texas (1366), Mato Grosso do Sul (997), Alaska (580), Florida (482), California (474)
# 5   country    28207 (0.22%)   object   US (12576), BR (2824), AU (1608), CA (1172), DE (479)
# 6   elevation  28270 non-null  float64  Min: -1266.00, Max: 14965.00, Median: 720.00, Mean: 1184.86
# 7   lat        28270 non-null  float64  Min: -90.00, Max: 82.52, Median: 34.77, Mean: 23.19
# 8   lon        28270 non-null  float64  Min: -179.88, Max: 179.95, Median: -73.74, Mean: -38.58
# 9   tz         28270 non-null  object   America/Chicago (5269), America/New_York (3444), America/Los_Angeles (1297), America/Denver (961), America/Sao_Paulo (948)
# 10  lid        12610 (55.39%)  object   only unique Values

# %%
explore_features(df_iata)
# Out:
# ID  Name          non-null count  D-Type  Feature Summary
# 0   Country       89 non-null     object  US (10), JP (9), BR (7), GB (7), IT (5)
# 1   City Code     89 non-null     object  LON (5), OSA (3), MIL (3), SAO (3), MOW (3)
# 2   City Name     89 non-null     object  London (5), Osaka (3), Milan (3), Sao Paulo (3), Moscow (3)
# 3   Airport Code  89 non-null     object  only unique Values
# 4   Airport Name  89 non-null     object  International (2)

# %%
explore_features(df_train)
# Out:
# ID  Name    non-null count   D-Type   Feature Summary
# 0   ID      107833 non-null  object   only unique Values
# 1   DATOP   107833 non-null  object   2018-08-31 (183), 2016-08-25 (179), 2018-08-27 (178), 2016-08-26 (178), 2016-08-30 (177)
# 2   FLTID   107833 non-null  object   WKL 0000  (3105), TU 0613  (1284), TU 0397  (1184), AOG 0000  (1103), TU 0634  (1075)
# 3   DEPSTN  107833 non-null  object   TUN (42522), DJE (10252), ORY (6755), MIR (5248), MRS (2845)
# 4   ARRSTN  107833 non-null  object   TUN (42572), DJE (10198), ORY (6755), MIR (5251), MRS (2845)
# 5   STD     107833 non-null  object   2017-06-23 06:00:00 (8), 2017-08-18 06:00:00 (7), 2017-07-21 06:00:00 (7), 2017-08-11 06:00:00 (7), 2016-01-28 07:00:00 (7)
# 6   STA     107833 non-null  object   2016-01-19 01.00.00 (6), 2018-04-07 01.00.00 (6), 2017-01-26 01.00.00 (6), 2018-02-26 09.00.00 (6), 2018-01-29 17.00.00 (6)
# 7   STATUS  107833 non-null  object   5 unique | ATA (93679), SCH (13242), DEP (467), RTR (294), DEL (151)
# 8   AC      107833 non-null  object   TU 320IMU (4724), TU 320IMW (4685), TU 320IMT (4634), TU 320IMR (4601), TU 320IMV (4589)
# 9   target  107833 non-null  float64  Min: 0.00, Max: 3451.00, Median: 14.00, Mean: 48.73
